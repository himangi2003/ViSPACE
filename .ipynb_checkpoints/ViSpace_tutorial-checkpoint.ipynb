# %% [markdown]
# # ViP-SegD Pipeline — Interactive Notebook
#
# End-to-end whole-slide image (WSI) analysis for H&E pathology slides:
# tile extraction → semantic segmentation → spatial feature extraction.
#
# ---
#
# ## Pipeline overview
#
# ```
# WSI (.svs/.tif)
#   │
#   ├─ Stage 1 · Tessellation          tile the slide with Mussel
#   ├─ Stage 2 · Segmentation          run ViP-SegD model per tile
#   ├─ Stage 3 · Stitching             assemble tiles → GeoJSON + PNG
#   │
#   ├─ Stage 4 · Tumor ROI Overlay     cluster tumour tiles → ROI boxes
#   ├─ Stage 5 · Cluster TSR/sTILs     score TSR & TILs per cluster polygon
#   │
#   ├─ Stage 6 · Immune Proximity      TIL distance/phenotype features
#   ├─ Stage 7 · Necrosis Proximity    necrosis distance/phenotype features
#   └─ Stage 8 · Tumour Morphology     island shape, fragmentation, NND
# ```
#
# Every stage writes its outputs to a predictable subdirectory under `cfg.OUT_DIR/<slide_name>/`.
# If an output already exists the stage is **automatically skipped**, so interrupted runs resume cleanly.
#
# ---
#
# **How to use this notebook**
#
# 1. Make sure you go through all the prechecks in **Precheck 1-3**.
# 2. Run cells after that top-to-bottom for a guided walkthrough, *or*
# 3. Jump straight to **Cell 4** to run the full pipeline in one call.
# 4. Use later cells to inspect outputs interactively after the run.

# %% [markdown]
# ## Precheck 1 — Hugging Face Login
#
# Make sure you have the hugging face login set

# %%
# Cell 1 — HF auth
import os
from huggingface_hub import whoami

# ✏ Paste your HF access token here (Read role is sufficient)
HF_ACCESS_TOKEN = "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"

# Verify the token is valid and print your username
user = whoami(token=HF_ACCESS_TOKEN)
print(f"Authenticated as: {user['name']}")

# Expose the token to all HF libraries for the rest of the session
os.environ["HF_TOKEN"] = HF_ACCESS_TOKEN
print("HF_TOKEN environment variable set.")
# Out:
# Authenticated as: himangi2003
# HF_TOKEN environment variable set.

# %% [markdown]
# ## Precheck 2 — Set Pipeline Configuration
#
# Set `WSI_PATH` to your slide file and `OUT_DIR` to where results should be written. Also set your `MUSSEL_DIR` where you cloned the mussel directory. See the `README.md` for instructions on downloading Mussel
#
#
# All other settings have sensible defaults — adjust only what you need. For reference chec the `config.py` file and Pipeline manual document in the folder
#
# | Parameter | Meaning | Default |
# |-----------|---------|---------|
# | `WSI_PATH` | Path to the `.svs` / `.tif` slide | *(required)* |
# | `OUT_DIR` | Root output directory | *(required)* |
# | `MPP` | Microns-per-pixel at the magnification stored in `wx/wy` coordinates | `0.25` |
# | `CHECKPOINT` | Path to the ViP-SegD model checkpoint | *(required)* |
# | `PATCH_SIZE` | Tile side-length in pixels | `224` |
# | `WORKERS` | Parallel workers for Mussel tessellation | `4` |
# | `ROI_SIZE_UM` | ROI box edge-length in microns | `200.0` |
# | `CLUSTER_BUFFER_UM` | Buffer added around ROI boxes when building cluster polygons | `200.0` |
# | `TILS_DENOMINATOR` | sTILs scoring variant: `salgado` / `stroma_plus_inflammatory` / `tissue` | `salgado` |
# | `MORPHOLOGY_MIN_ISLAND_AREA_UM2` | Minimum tumour island area for shape metrics | `1000.0` |

# %%
# Cell 2 — build config
from config import PipelineConfig

cfg = PipelineConfig(
    WSI_PATH   = "TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69.tif",
    CHECKPOINT = "TNBC_weights/TNBC_best.pt",
    MUSSEL_DIR = "Mussel",
    OUT_DIR    = "vipsegd_output",
    BATCH_SIZE = 96
    
)
cfg
# Out:
# PipelineConfig(OUT_DIR='vipsegd_output', CHECKPOINT='TNBC_weights/TNBC_best.pt', WSI_PATH='TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69.tif', MUSSEL_DIR='Mussel', PATCH_SIZE=224, WORKERS=4, SEGMENT_THRESH=20, THUMBNAIL_SIZE=(1024, 1024), VIRCHOW2_PATH=None, DEVICE='cuda', BATCH_SIZE=96, WHITE_THRESH=220, MPP=0.25, STEP_X=444, STEP_Y=444, MAX_PX=4096, ALPHA=0.6, THUMB_MAX=2048, ROI_SIZE_UM=200.0, ROI_MIN_TUMOR_FRAC=0.2, ROI_MAX_NECROSIS=0.5, ROI_MIN_CLUSTER_TILES=3, ROI_CONNECTIVITY=8, ROI_MERGE_GAP_UM=60.0, ROI_THUMB_WIDTH=1800, ROI_COLOR_BY_CLUSTER=True, TILS_DENOMINATOR='salgado', CLUSTER_BUFFER_UM=200.0, CLUSTER_MIN_ROI_BOXES=5, CLUSTER_MIN_POLYGON_AREA_PX2=1.0, CLUSTER_MAX_AREA_QUANTILE=1.0, CLUSTER_MAX_AREA_MAD_Z=0.0, CLUSTER_MIN_TISSUE_FRACTION=0.1, CLUSTER_MIN_TSR_DENOM_PX2=5000.0, CLUSTER_MIN_TILS_DENOM_PX2=5000.0, CLUSTER_NO_OVERLAY=False, IMMUNE_PROXIMITY_THRESHOLDS_UM=[20, 50, 100, 200], IMMUNE_CONTACT_TOLERANCE_UM=5.0, IMMUNE_DESERT_MAX_AREA_UM2=1000.0, IMMUNE_PENETRATED_MIN_INTRA_FRAC=0.3, IMMUNE_MARGIN_MIN_PCT_50UM=50.0, IMMUNE_EXCLUDED_MIN_MEDIAN_UM=100.0, IMMUNE_PERITUMORAL_MAX_MEDIAN_UM=100.0, NECROSIS_PROXIMITY_THRESHOLDS_UM=[50.0, 100.0], NECROSIS_CONTACT_TOLERANCE_UM=5.0, NECROSIS_IMMUNE_COUPLING_THRESHOLD_UM=20.0, NECROSIS_MIN_COMPONENT_AREA_UM2=500.0, NECROSIS_ABSENT_MAX_AREA_UM2=500.0, NECROSIS_CENTRAL_MIN_INTRA_FRAC=0.5, NECROSIS_PERITUMOURAL_MIN_PCT_100UM=60.0, NECROSIS_IMMUNE_ADJACENT_MIN_COUPLING=0.2, NECROSIS_DISTANT_MIN_MEDIAN_UM=150.0, MORPHOLOGY_MIN_ISLAND_AREA_UM2=1000.0, MORPHOLOGY_SAVE_ISLAND_QC=False, MORPHOLOGY_TUMOR_CLASS_NAMES={'tumour', 'tumor', 'Tumour', 'Tumor'})

# %% [markdown]
# ## Precheck 3 — Environment and GPU check
#
# Verify that all required packages are importable before starting and also check GPU compatibility and compute
# If anything is missing the `pip install` line will install it.

# %%
from environment_check import run_environment_check

if not run_environment_check(cfg):
    raise SystemExit("Fix the environment issues above before running.")
# Out:
# ============================================================
#   Python version
# ============================================================
#   Running     : Python 3.11.15
#   [OK]   Python 3.11 meets minimum 3.10
#
# ============================================================
#   Required packages
# ============================================================
#   [OK]   torch              (torch) — 2.5.1+cu121
#   [OK]   torchvision        (torchvision) — 0.20.1+cu121
#   [OK]   timm               (timm) — 1.0.17
#   [OK]   huggingface_hub    (huggingface_hub) — 0.33.4
#   [OK]   numpy              (numpy) — 2.2.6
#   [OK]   pandas             (pandas) — 2.3.1
#   [OK]   cv2                (opencv-python-headless) — 4.12.0
#   [OK]   PIL                (pillow) — 11.3.0
#   [OK]   tqdm               (tqdm) — 4.67.1
#   [OK]   shapely            (shapely) — 2.1.1
#   [OK]   geopandas          (geopandas) — 1.1.1
#   [OK]   scipy              (scipy) — 1.16.0
#   [OK]   matplotlib         (matplotlib) — 3.10.3
#   [OK]   ml_dtypes          (ml_dtypes) — 0.5.4
#   [OK]   open_clip          (open_clip_torch) — 3.3.0
#   [OK]   omegaconf          (omegaconf) — 2.3.0
#   [OK]   h5py               (h5py) — 3.14.0
#
# ============================================================
#   Optional packages
# ============================================================
#   [OK]   openslide          (openslide-python + openslide-bin) — 1.4.1
#
# ============================================================
#   GPU / precision
# ============================================================
#   GPU(s) found: 1
#   Device 0    : NVIDIA GeForce RTX 2080 Ti
#   Compute cap : 7.5
#   AMP dtype   : torch.float16  (tensor-core accelerated)
#   [OK]   Tensor cores available for torch.float16 — full mixed-precision speedup expected.
#   VRAM        : 11.3 GB
#
# ============================================================
#   HuggingFace authentication
# ============================================================
#   [OK]   HF_TOKEN is set and valid — authenticated as himangi2003
#
# ============================================================
#   Config paths
# ============================================================
#   [OK]   cfg.WSI_PATH    exists: TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69.tif
#   [OK]   cfg.CHECKPOINT  exists: TNBC_weights/TNBC_best.pt
#   [OK]   cfg.MUSSEL_DIR  exists: Mussel
#   [WARN] cfg.OUT_DIR     does not exist yet — will be created on first run: vipsegd_output
#
# ============================================================
#   Summary
# ============================================================
#   [OK]   Python version
#   [OK]   Required packages
#   [OK]   GPU / precision
#   [OK]   HuggingFace auth
#   [OK]   Config paths
#
#   All required checks passed — safe to run the pipeline.

# %% [markdown]
# ---
# ## Stage 1: Tessellation
#
# **What happens:** Mussel tiles the WSI at `cfg.PATCH_SIZE × cfg.PATCH_SIZE` pixels.
# An Otsu tissue mask is computed to skip glass/background tiles.
# Outputs a directory of PNG patches and an HDF5 index.
#
# **Key outputs:**
# - `tessellation/patches/<slide>_<wx>_<wy>.png` — one file per tissue tile
# - `tessellation/<slide>.h5` — coordinate index (sentinel file for this stage)
# - `tessellation/thumbnail.png` — low-resolution slide overview
# - `tessellation/mask.png` — binary tissue mask
#
# **Config knobs:** `MUSSEL_DIR`, `PATCH_SIZE`, `SEGMENT_THRESH`, `THUMBNAIL_SIZE`, `WORKERS`

# %%
# — tessellate
from tessellate import run_tessellation

tess_dir = run_tessellation(cfg.WSI_PATH, cfg)
tess_dir
# Out:
# =======================================================
#   Tessellation
#   Slide      : TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69.tif
#   Mussel dir : Mussel
#   Patch size : 224
#   Workers    : 4
#   Output     : vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/tessellation
# =======================================================
#
#   Running Mussel tessellation (this may take a while)...
#
#   Done. 9,234 patches saved → vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/tessellation
# 'vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/tessellation'

# %% [markdown]
# ## Stage 2: Segmentation
#
# **What happens:** Loads the ViP-SegD model (Virchow2 encoder + ViT2SegDecoder) from
# `cfg.CHECKPOINT`.  Each tile is passed through the model to produce a per-pixel class
# map saved as a `.npy` file.  Near-white background pixels are masked to `SEG_IGNORE`.
#
# **Classes:** Tumour · Stroma · Inflammatory · Necrosis · Others
#
# **Key outputs:**
# - `segmentation/<tile>_seg.npy` — per-tile int32 class map *(temporary, deleted by Stage 3)*
# - `segmentation/manifest.csv` — `tile, wx, wy, npy_path` for every predicted tile
#   *(sentinel file for this stage)*
#
# **Config knobs:** `CHECKPOINT`, `MPP`
#
# > **Hardware note:** this stage runs on GPU if `torch.cuda.is_available()`, otherwise CPU.
# > Expect ~3–10 min for a typical TCGA slide on GPU.

# %%
# segment
from segmenter import run_segmentation

manifest_csv = run_segmentation(cfg.WSI_PATH, cfg)
manifest_csv
# Out:
# =======================================================
#   Segmentation
#   Slide      : TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69
#   Tiles      : 9,234
#   Batch size : 96
#   Device     : cuda
#   Checkpoint : TNBC_best.pt
#   Output     : vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/segmentation
# =======================================================
#
#   Loading checkpoint: TNBC_best.pt
#   Loading Virchow2 from: hf-hub:paige-ai/Virchow2
#   Virchow2: 0.63B params | frozen | cuda
#   epoch=12  macro_dice=0.739975049446258  device=cuda
#   Decoder params: 9.5M
#   AMP dtype  : torch.float16
# Running segmentation: 100%|██████████| 9234/9234 [01:55<00:00, 79.97tile/s]
#   Manifest saved → vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/segmentation/manifest.csv
#   Done. 9,234 tiles segmented → vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/segmentation
# 'vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/segmentation/manifest.csv'

# %% [markdown]
# ## Stage 3: Stitching
#
# **What happens:** Reads every per-tile `.npy` class map from the manifest, resizes
# each to fill its grid slot (eliminating checkerboard gaps), and places it onto a
# large integer canvas in WSI level-0 pixel coordinates.
#
# The stitched canvas is then vectorised into GeoJSON polygons — one feature per
# connected region, with `classification.name` set to the tissue class.  This
# GeoJSON is the input for all downstream spatial-analysis stages.
#
# Finally, all `.npy` scratch files are **automatically deleted** once both final
# outputs exist.
#
# **Key outputs:**
# - `segmentation/segmentation_all_classes.geojson` ← **primary input for stages 4–8**
# - `segmentation/<slide>_segmentation.png` — colour overlay with legend
#
# **Config knobs:** `MPP` (used for axis step inference fallback)

# %%
# stitch + GeoJSON
from stitch import run_stitching

stitch_results = run_stitching(cfg.WSI_PATH, cfg)
stitch_results
# Out:
# =======================================================
#   Stitching + GeoJSON
#   Slide      : TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69
#   Manifest   : vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/segmentation/manifest.csv
#   Output     : vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/segmentation
# =======================================================
#
# =======================================================
#   Stitching
#   Slide      : TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69
#   Tiles      : 9,234
#   Canvas     : 29748x30192 px  origin=(1664,704)
#   Step       : 222x222  (auto-inferred)
# =======================================================
# Stitching segmentation tiles: 100%|██████████| 9234/9234 [00:26<00:00, 345.20tile/s]
#   Saved npy  : stitched_seg.npy
#   Saved png  : TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69_segmentation.png
#
#   Class distribution:
#     Tumour               82,498,099 px  (20.8%)  ████████
#     Stroma               195,929,552 px  (49.3%)  ███████████████████
#     Inflammatory         86,062,447 px  (21.7%)  ████████
#     Necrosis             10,571,963 px  (2.7%)  █
#     Others               22,329,556 px  (5.6%)  ██
#
# =======================================================
#   GeoJSON extraction
#   Canvas   : 29748x30192 px  origin=(1664,704)
#     Tumour               82,498,099 px  (20.8%)
#     Stroma               195,929,552 px  (49.3%)
#     Inflammatory         86,062,447 px  (21.7%)
#     Necrosis             10,571,963 px  (2.7%)
#     Others               22,329,556 px  (5.6%)
# Writing GeoJSON:  20%|██        | 1/5 [00:05<00:20,  5.20s/class]
#   Tumour               1,831 polygons  ~11.07 MB
# Writing GeoJSON:  40%|████      | 2/5 [00:13<00:21,  7.20s/class]
#   Stroma               5,908 polygons  ~34.23 MB
# Writing GeoJSON:  60%|██████    | 3/5 [00:18<00:12,  6.22s/class]
#   Inflammatory         3,833 polygons  ~15.03 MB
# Writing GeoJSON:  80%|████████  | 4/5 [00:22<00:05,  5.09s/class]
#   Necrosis             1,719 polygons  ~5.39 MB
# Writing GeoJSON: 100%|██████████| 5/5 [00:27<00:00,  5.46s/class]
#   Others               4,486 polygons  ~15.21 MB
#   Combined : 17,777 polygons  72.81 MB  → segmentation_all_classes.geojson
# Cleaning temporary files: 100%|██████████| 9235/9235 [00:01<00:00, 4792.61file/s]
#   Cleaned up : 9,235 .npy files from segmentation/
#
#   Done.
#   Colour PNG   : TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69_segmentation.png
#   Combined GJ  : segmentation_all_classes.geojson
#   .npy removed : 9,235
# {'slide_name': 'TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69',
#  'manifest_csv': 'vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/segmentation/manifest.csv',
#  'stitched_png': 'vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/segmentation/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69_segmentation.png',
#  'geojson': {'combined': 'vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/segmentation/segmentation_all_classes.geojson'},
#  'meta': {'manifest_csv': 'vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/segmentation/manifest.csv',
#   'stitched_seg_npy': 'vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/segmentation/stitched_seg.npy',
#   'stitched_seg_png': 'vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/segmentation/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69_segmentation.png',
#   'slide_name': 'TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69',
#   'origin': [1664, 704],
#   'canvas_shape': [30192, 29748],
#   'original_tile_shape': [224, 224],
#   'step': [222, 222],
#   'step_inferred': True,
#   'missing_npy': 0},
#  'npys_removed': 9235}

# %% [markdown]
# ## Stage 4: Tumor ROI Overlay
#
# **What happens:** Reads the tile manifest and filters for tumour-rich tiles
# (`frac_Tumour ≥ cfg.ROI_MIN_TUMOR_FRAC`), then runs a 5-step pipeline:
#
# 1. **Filter** tumour tiles by minimum tumour fraction
# 2. **Cluster** tiles into spatially-connected clumps via BFS on the tile grid
# 3. **Merge** nearby clumps within `cfg.ROI_MERGE_GAP_UM` of each other (union-find)
# 4. **Box** each clump with non-overlapping square ROI boxes of `cfg.ROI_SIZE_UM` µm
# 5. **Overlay** boxes on a pseudo-thumbnail and optionally the real WSI thumbnail
#
# **Key outputs:**
# - `tumor_roi_overlay/tumor_roi_boxes.csv` ← **input for Stage 5**
# - `tumor_roi_overlay/tumor_roi_boxes_pseudo_thumbnail.png`
# - `tumor_roi_overlay/tumor_roi_boxes_wsi_thumbnail.png` *(if WSI file exists on disk)*
#
# **Config knobs:** `MPP`, `ROI_SIZE_UM`, `ROI_MIN_TUMOR_FRAC`, `ROI_MAX_NECROSIS`,
# `ROI_MIN_CLUSTER_TILES`, `ROI_CONNECTIVITY`, `ROI_MERGE_GAP_UM`
#
# > **Why ROI boxes?** The GeoJSON segmentation covers the entire scanned area including
# > stroma-only and background regions. ROI boxes focus downstream scoring polygons
# > on tissue regions that actually contain tumour.

# %%
# tumor ROI clustering + overlay
from tumor_roi_overlay import run_tumor_roi_overlay

roi_results = run_tumor_roi_overlay(cfg.WSI_PATH, cfg)
roi_results
# Out:
# =======================================================
#   Tumor ROI overlay
#   Slide      : TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69
#   Manifest   : vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/segmentation/manifest.csv
#   ROI size   : 200 µm  →  800.0 px  (mpp=0.25)
#   Output     : vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/spatial_feature_results/tumor_roi_overlay
# =======================================================
# Building ROI boxes: 100%|██████████| 12/12 [00:00<00:00, 20.42cluster/s]
#   Wrote: tumor_roi_boxes.csv  (341 boxes)
#   Generated 341 ROI box(es) across 10 tumor clump(s).
# Saving pseudo-thumbnail overlay:   0%|          | 0/1 [00:00<?, ?image/s]
# Rendering pseudo-thumbnail:   0%|          | 0/9234 [00:00<?, ?tile/s]
# Rendering pseudo-thumbnail:  27%|██▋       | 2476/9234 [00:00<00:00, 24759.32tile/s]
# Rendering pseudo-thumbnail:  54%|█████▍    | 4997/9234 [00:00<00:00, 25018.89tile/s]
# Rendering pseudo-thumbnail:  81%|████████  | 7500/9234 [00:00<00:00, 25019.92tile/s]
# Saving pseudo-thumbnail overlay:   0%|          | 0/1 [00:01<?, ?image/s]
#   Wrote: tumor_roi_boxes_pseudo_thumbnail.png
# Saving WSI thumbnail overlay:   0%|          | 0/1 [00:02<?, ?image/s]
#   Wrote: tumor_roi_boxes_wsi_thumbnail.png
#   (WSI metadata mpp-x = 0.5054 µm/px, for reference)
#
#   Done.
# {'slide_name': 'TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69',
#  'manifest_csv': 'vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/segmentation/manifest.csv',
#  'roi_csv': 'vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/spatial_feature_results/tumor_roi_overlay/tumor_roi_boxes.csv',
#  'pseudo_png': 'vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/spatial_feature_results/tumor_roi_overlay/tumor_roi_boxes_pseudo_thumbnail.png',
#  'wsi_png': 'vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/spatial_feature_results/tumor_roi_overlay/tumor_roi_boxes_wsi_thumbnail.png',
#  'n_boxes': 341,
#  'n_clusters': 10}

# %%
# Cell 11 (optional) — inspect a result inline, e.g. the ROI overlay image
from PIL import Image
Image.open(roi_results["pseudo_png"])
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2800x2400>

# %% [markdown]
# ## Stage 5: Cluster TSR / sTILs Scoring
#
# **What happens:** Dissolves the ROI boxes for each tumour cluster into a single
# convex scoring polygon, buffers it by `cfg.CLUSTER_BUFFER_UM` µm to capture
# peritumoural stroma, then clips and non-overlapping-assigns polygons across clusters.
#
# For each scoring polygon, all GeoJSON segmentation polygons that intersect it are
# clipped and summed per class.  Background (unsegmented pixels) is tracked separately
# and **never** enters any denominator.
#
# **Metrics computed:**
#
# | Metric | Formula | Denominator |
# |--------|---------|-------------|
# | TSR | Stroma / (Tumour + Stroma) | T + S only |
# | sTILs (Salgado) | Inflammatory / Stroma × 100 | Stroma |
# | sTILs (stromal) | Inflammatory / (Stroma + Inflam) × 100 | S + I |
# | sTILs (tissue) | Inflammatory / Viable × 100 | T+S+I+O |
#
# **Key outputs:**
# - `cluster_tils_tsr_score/cluster_scoring_polygons.geojson` ← **input for stages 6–8**
# - `cluster_tils_tsr_score/tils_tsr_by_cluster.csv`
# - `cluster_tils_tsr_score/tils_tsr_wsi_summary.csv`
# - `cluster_tils_tsr_score/cluster_tils_tsr_overlay.png`

# %%
# cluster TSR / sTILs scoring
from cluster_tils_tsr_score import run_cluster_tils_tsr_score

tsr_results = run_cluster_tils_tsr_score(cfg.WSI_PATH, cfg)
tsr_results["wsi_summary"]

# %% [markdown]
# ##  Stage 6: Immune Proximity Features
#
# **What happens:** For each cluster scoring polygon, all Inflammatory-class polygons
# are clipped to the cluster boundary.  For each resulting inflammatory component,
# its `representative_point()` (guaranteed inside the polygon) is located relative
# to the tumour boundary:
#
# - **Negative distance** → inside tumour (intratumoral TIL)
# - **Positive distance** → outside tumour (extratumoral TIL)
#
# **Immune spatial phenotype** (Galon & Bruni 2020 classification hierarchy):
#
# | Phenotype | Criterion |
# |-----------|-----------|
# | `immune-desert` | total TIL area < 1,000 µm² |
# | `immune-penetrated` | ≥ 30% intratumoral |
# | `margin-localized` | ≥ 50% within 50 µm of boundary |
# | `immune-excluded` | median extratumoral distance ≥ 100 µm |
# | `peritumoral` | present, close, but not penetrating |
#
# **Key outputs:**
# - `immune_proximity/immune_proximity_by_cluster.csv`
# - `immune_proximity/immune_proximity_wsi_summary.csv`
# - `immune_proximity/immune_proximity_plot.png`

# %%
# immune / TIL proximity features
from immune_proximity_features import run_immune_proximity_features

immune_results = run_immune_proximity_features(cfg.WSI_PATH, cfg)
immune_results

# %% [markdown]
# ## Stage 7: Necrosis Proximity Features
#
# **What happens:** The same signed-distance approach as Stage 6, but applied to
# Necrosis-class components.  Additionally computes nearest-distance to both
# Inflammatory and Stroma polygons within each cluster (TNF-proxy / stromal
# remodelling proxy).
#
# **Necrosis spatial phenotype** (classification hierarchy):
#
# | Phenotype | Criterion |
# |-----------|-----------|
# | `necrosis-absent` | total area < 500 µm² |
# | `tumour-central` | intratumoral fraction ≥ 50% |
# | `peritumoural` | ≥ 60% within 100 µm of tumour boundary |
# | `immune-adjacent` | ≥ 20% of necrosis near Inflammatory tissue |
# | `stromal-distant` | present but spatially decoupled |
#
# **Extra features vs immune proximity:**
# - `necrosis_immune_coupling_index` — fraction of necrosis within `NECROSIS_IMMUNE_COUPLING_THRESHOLD_UM` of inflammatory tissue
# - `necrosis_stroma_min_dist_aw_median_um` — distance to nearest stroma
# - `necrosis_to_tumor_ratio` — clinically used ratio
#
# **Key outputs:**
# - `necrosis_proximity/necrosis_proximity_by_cluster.csv`
# - `necrosis_proximity/necrosis_proximity_wsi_summary.csv`
# - `necrosis_proximity/necrosis_distance_figure.png`
# - `necrosis_proximity/necrosis_tissue_context_figure.png`

# %%
# necrosis proximity features
from necrosis_proximity_features import run_necrosis_proximity_features

necrosis_results = run_necrosis_proximity_features(cfg.WSI_PATH, cfg)
necrosis_results

# %% [markdown]
# ## Stage 8: Tumour Morphology Features
#
# **What happens:** Tumour-class polygons from the segmentation GeoJSON are clipped
# to each cluster scoring polygon, then dissolved into a single multi-island geometry.
# Each connected island is measured individually and aggregated with area-weighting
# (large nests count more than tiny fragments).
#
# > **Important:** always set `cfg.MORPHOLOGY_MIN_ISLAND_AREA_UM2 ≥ 1000` to filter
# > single-cell pixel-segmentation fragments before computing shape metrics.
# > Report this threshold alongside any shape metric.
#
# **Feature groups:**
#
# | Group | Features |
# |-------|---------|
# | Tumour burden | `tumor_area_mm2`, `tumor_fraction_of_cluster`, `tumor_perimeter_um` |
# | Shape (area-weighted) | `tumor_compactness_mean`, `tumor_solidity_mean`, `tumor_elongation_mean` |
# | Fragmentation | `tumor_n_islands`, `tumor_largest_patch_index`, `tumor_fragmentation_index`, `tumor_effective_patches` |
# | Size distribution | `tumor_island_area_mean/median/p90/max_um2`, `tumor_island_area_cv` |
# | Spatial spread | `tumor_island_nnd_median_um`, `tumor_spread_frac`, `tumor_convex_hull_fill` |
# | Size tiers | `tumor_n_islands_fragment/micro/small/large` |
#
# **Key outputs:**
# - `tumor_morphology/tumor_core_features_by_cluster.csv`
# - `tumor_morphology/tumor_core_wsi_summary.csv`
# - `tumor_morphology/tumor_island_qc.csv` *(when `cfg.MORPHOLOGY_SAVE_ISLAND_QC = True`)*

# %%
# tumor morphology features
from tumor_morphology_features import run_tumor_morphology_features

morphology_results = run_tumor_morphology_features(cfg.WSI_PATH, cfg)
morphology_results
# Out:
# =======================================================
#   Tumour morphology features
#   Slide              : TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69
#   min_island_area_um2: 1000
#   Clusters           : cluster_scoring_polygons.geojson
#   Output             : vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/spatial_feature_results/tumor_morphology
# =======================================================
#   Loaded 1,831 tumour polygons from 17,777 GeoJSON features.
# Computing tumour morphology: 100%|██████████| 3/3 [00:04<00:00,  1.43s/cluster]
#   Wrote: tumor_core_features_by_cluster.csv
#   Wrote: tumor_core_wsi_summary.csv
#   Wrote: tumor_area_by_cluster.png
#   Wrote: tumor_fraction_by_cluster.png
#   Wrote: tumor_islands_by_cluster.png
#   Wrote: tumor_fragmentation_by_cluster.png
#   Wrote: tumor_fragmentation_landscape.png
#
#   === Tumour morphology summary ===
#   Clusters scored:         3
#   Total tumour area:       5.615 mm²
#   Total islands (filtered):244
#   Mean fragmentation index:0.634
#   Mean compactness:        0.104
#
#   Done.
# {'slide_name': 'TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69',
#  'cluster_geojson': 'vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/spatial_feature_results/cluster_tils_tsr_score/cluster_scoring_polygons.geojson',
#  'segmentation_geojson': 'vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/segmentation/segmentation_all_classes.geojson',
#  'core_csv': 'vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/spatial_feature_results/tumor_morphology/tumor_core_features_by_cluster.csv',
#  'summary_csv': 'vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/spatial_feature_results/tumor_morphology/tumor_core_wsi_summary.csv',
#  'island_qc_csv': None,
#  'tumor_area_by_cluster_png': 'vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/spatial_feature_results/tumor_morphology/tumor_area_by_cluster.png',
#  'tumor_fraction_by_cluster_png': 'vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/spatial_feature_results/tumor_morphology/tumor_fraction_by_cluster.png',
#  'tumor_islands_by_cluster_png': 'vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/spatial_feature_results/tumor_morphology/tumor_islands_by_cluster.png',
#  'tumor_fragmentation_by_cluster_png': 'vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/spatial_feature_results/tumor_morphology/tumor_fragmentation_by_cluster.png',
#  'tumor_fragmentation_landscape_png': 'vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/spatial_feature_results/tumor_morphology/tumor_fragmentation_landscape.png'}

# %% [markdown]
# ##  Run the full pipeline in one go
#
# One call to `run_vipsegd()` executes all eight stages in dependency order.
#
# **Resumable** — stages whose primary output already exists on disk are skipped automatically.
# Re-run this cell after a crash and it will pick up from where it left off.
#
# **Selective re-run** — pass `force_stages={...}` to re-execute specific stages:
# ```python
# results = run_vipsegd(WSI_PATH, cfg, force_stages={'segmentation', 'stitching'})
# ```
#
# **Subset run** — pass `stages={...}` to run only certain stages
# (their prerequisites must already be on disk):
# ```python
# results = run_vipsegd(WSI_PATH, cfg, stages={'immune_proximity', 'tumor_morphology'})
# ```

# %%
# run all 8 stages end-to-end
from run_vipsegd import run_vipsegd

results = run_vipsegd(cfg.WSI_PATH, cfg)
results["success"]

failed = {name: info for name, info in results['stages'].items()
          if info.get('status') == 'failed'}

if not failed:
    print("No stages failed in the last run.")
else:
    for stage_name, info in failed.items():
        print("=" * 60)
        print(f"FAILED STAGE: {stage_name}")
        print("=" * 60)
        print(info["error"])
# Out:
# ############################################################
#   ViP-SegD pipeline
#   Slide : TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69
#   Stages: tessellation, segmentation, stitching, tumor_roi_overlay, cluster_tils_tsr_score, immune_proximity, necrosis_proximity, tumor_morphology
# ############################################################
#
#   ▶  [tessellation] starting …
#
# =======================================================
#   Tessellation
#   Slide      : TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69.tif
#   Mussel dir : Mussel
#   Patch size : 224
#   Workers    : 4
#   Output     : vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/tessellation
# =======================================================
#
#   Running Mussel tessellation (this may take a while)...
#
#   Done. 9,234 patches saved → vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/tessellation
#   ✓  [tessellation] done in 74.8s
#
#   ▶  [segmentation] starting …
#
# =======================================================
#   Segmentation
#   Slide      : TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69
#   Tiles      : 9,234
#   Batch size : 96
#   Device     : cuda
#   Checkpoint : TNBC_best.pt
#   Output     : vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/segmentation
# =======================================================
#
#   Loading checkpoint: TNBC_best.pt
#   Loading Virchow2 from: hf-hub:paige-ai/Virchow2
#   Virchow2: 0.63B params | frozen | cuda
#   epoch=12  macro_dice=0.739975049446258  device=cuda
#   Decoder params: 9.5M
#   AMP dtype  : torch.float16
# Running segmentation: 100%|██████████| 9234/9234 [01:55<00:00, 80.25tile/s]
#   Manifest saved → vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/segmentation/manifest.csv
#   Done. 9,234 tiles segmented → vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/segmentation
#   ✓  [segmentation] done in 125.1s
#
#   ▶  [stitching] starting …
#
# =======================================================
#   Stitching + GeoJSON
#   Slide      : TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69
#   Manifest   : vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/segmentation/manifest.csv
#   Output     : vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/segmentation
# =======================================================
#
# =======================================================
#   Stitching
#   Slide      : TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69
#   Tiles      : 9,234
#   Canvas     : 29748x30192 px  origin=(1664,704)
#   Step       : 222x222  (auto-inferred)
# =======================================================
# Stitching segmentation tiles: 100%|██████████| 9234/9234 [00:28<00:00, 324.33tile/s]
#   Saved npy  : stitched_seg.npy
#   Saved png  : TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69_segmentation.png
#
#   Class distribution:
#     Tumour               82,498,099 px  (20.8%)  ████████
#     Stroma               195,929,552 px  (49.3%)  ███████████████████
#     Inflammatory         86,062,447 px  (21.7%)  ████████
#     Necrosis             10,571,963 px  (2.7%)  █
#     Others               22,329,556 px  (5.6%)  ██
#
# =======================================================
#   GeoJSON extraction
#   Canvas   : 29748x30192 px  origin=(1664,704)
#     Tumour               82,498,099 px  (20.8%)
#     Stroma               195,929,552 px  (49.3%)
#     Inflammatory         86,062,447 px  (21.7%)
#     Necrosis             10,571,963 px  (2.7%)
#     Others               22,329,556 px  (5.6%)
# Writing GeoJSON:  20%|██        | 1/5 [00:04<00:19,  4.77s/class]
#   Tumour               1,831 polygons  ~11.07 MB
# Writing GeoJSON:  40%|████      | 2/5 [00:12<00:19,  6.41s/class]
#   Stroma               5,908 polygons  ~34.23 MB
# Writing GeoJSON:  60%|██████    | 3/5 [00:17<00:11,  5.72s/class]
#   Inflammatory         3,833 polygons  ~15.03 MB
# Writing GeoJSON:  80%|████████  | 4/5 [00:20<00:04,  4.80s/class]
#   Necrosis             1,719 polygons  ~5.39 MB
# Writing GeoJSON: 100%|██████████| 5/5 [00:25<00:00,  5.15s/class]
#   Others               4,486 polygons  ~15.21 MB
#   Combined : 17,777 polygons  72.81 MB  → segmentation_all_classes.geojson
# Cleaning temporary files: 100%|██████████| 9235/9235 [00:01<00:00, 4672.18file/s]
#   Cleaned up : 9,235 .npy files from segmentation/
#
#   Done.
#   Colour PNG   : TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69_segmentation.png
#   Combined GJ  : segmentation_all_classes.geojson
#   .npy removed : 9,235
#   ✓  [stitching] done in 136.4s
#
#   ▶  [tumor_roi_overlay] starting …
#
# =======================================================
#   Tumor ROI overlay
#   Slide      : TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69
#   Manifest   : vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/segmentation/manifest.csv
#   ROI size   : 200 µm  →  800.0 px  (mpp=0.25)
#   Output     : vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/spatial_feature_results/tumor_roi_overlay
# =======================================================
# Building ROI boxes: 100%|██████████| 12/12 [00:00<00:00, 21.06cluster/s]
#   Wrote: tumor_roi_boxes.csv  (341 boxes)
#   Generated 341 ROI box(es) across 10 tumor clump(s).
# Saving pseudo-thumbnail overlay:   0%|          | 0/1 [00:00<?, ?image/s]
# Rendering pseudo-thumbnail:   0%|          | 0/9234 [00:00<?, ?tile/s]
# Rendering pseudo-thumbnail:  27%|██▋       | 2476/9234 [00:00<00:00, 24757.54tile/s]
# Rendering pseudo-thumbnail:  54%|█████▍    | 5016/9234 [00:00<00:00, 25130.38tile/s]
# Rendering pseudo-thumbnail:  82%|████████▏ | 7567/9234 [00:00<00:00, 25299.66tile/s]
# Saving pseudo-thumbnail overlay:   0%|          | 0/1 [00:01<?, ?image/s]
#   Wrote: tumor_roi_boxes_pseudo_thumbnail.png
# Saving WSI thumbnail overlay:   0%|          | 0/1 [00:02<?, ?image/s]
#   Wrote: tumor_roi_boxes_wsi_thumbnail.png
#   (WSI metadata mpp-x = 0.5054 µm/px, for reference)
#
#   Done.
#   ✓  [tumor_roi_overlay] done in 5.5s
#
#   ▶  [cluster_tils_tsr_score] starting …
#
# =======================================================
#   Cluster TSR / sTILs scoring
#   Slide      : TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69
#   ROI boxes  : tumor_roi_boxes.csv
#   GeoJSON    : segmentation_all_classes.geojson
#   sTILs denom: salgado
#   mpp        : 0.25
#   Output     : vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/spatial_feature_results/cluster_tils_tsr_score
# =======================================================
# Dissolving ROI boxes into cluster polygons: 100%|██████████| 10/10 [00:00<00:00, 252.01cluster/s]
#   Wrote: cluster_scoring_polygons.geojson
# Scoring clusters (TSR / sTILs):  67%|██████▋   | 2/3 [00:03<00:01,  1.57s/cluster]/cluster/home/srivash/ViP-SegD/VipSegD_v1/cluster_tils_tsr_scoring.py:939: UserWarning: Cluster 4: cross-class GeoJSON overlap is 7.3% of cluster area. Tissue areas may be slightly inflated.
#   cluster_scores = score_clusters(
# Scoring clusters (TSR / sTILs): 100%|██████████| 3/3 [00:03<00:00,  1.28s/cluster]
#   Wrote: tils_tsr_by_cluster.csv
#   Wrote: tils_tsr_wsi_summary.csv
# Saving cluster overlay:   0%|          | 0/1 [00:00<?, ?image/s]
# Rendering tissue overlay:   0%|          | 0/5 [00:00<?, ?class/s]
# Rendering tissue overlay:  20%|██        | 1/5 [00:00<00:02,  1.95class/s]
# Rendering tissue overlay:  40%|████      | 2/5 [00:00<00:00,  3.16class/s]
# Rendering tissue overlay:  60%|██████    | 3/5 [00:01<00:00,  2.07class/s]
# Rendering tissue overlay:  80%|████████  | 4/5 [00:01<00:00,  2.34class/s]
# Rendering tissue overlay: 100%|██████████| 5/5 [00:01<00:00,  3.00class/s]
#                                                                           /cluster/home/srivash/ViP-SegD/VipSegD_v1/cluster_tils_tsr_scoring.py:896: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   fig.tight_layout()
# Saving cluster overlay:   0%|          | 0/1 [00:03<?, ?image/s]
#   Wrote: cluster_tils_tsr_overlay.png
#
#   === WSI scoring summary ===
#   Clusters input / scored : 10 / 3
#   ROI boxes  input / scored: 341 / 323
#   WSI TSR                 : 42/58  (stroma-high)
#   WSI sTILs (Salgado)    : 51.82%
#   WSI sTILs (selected)   : 51.82%  [salgado]
#   Total cluster area      : 20.1143 mm²
#   Tissue fraction         : 0.923
#   ⚠ Cross-class GeoJSON overlap: mean=2.4% in 1 cluster(s). Tissue areas may be inflated.
#
#   Done.
#   ✓  [cluster_tils_tsr_score] done in 20.0s
#
#   ▶  [immune_proximity] starting …
#
# =======================================================
#   Immune proximity features
#   Slide    : TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69
#   Clusters : cluster_scoring_polygons.geojson
#   Output   : vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/spatial_feature_results/immune_proximity
# =======================================================
#   Clusters:             3
#   Segmentation regions: 17777
# Computing immune proximity: 100%|██████████| 3/3 [00:11<00:00,  3.85s/cluster]
#   Wrote: immune_proximity_by_cluster.csv
#   Wrote: immune_proximity_wsi_summary.csv
#   Wrote: immune_proximity_plot.png
#
#   === Immune proximity summary ===
#   Total TIL area:          4.012 mm²
#   TIL fraction of cluster: 0.199
#   Intratumoral fraction:   0.007
#   Median extratumoral dist:60.3 µm
#   Dominant phenotype:      peritumoral
#
#   Done.
#   ✓  [immune_proximity] done in 26.2s
#
#   ▶  [necrosis_proximity] starting …
#
# =======================================================
#   Necrosis proximity features
#   Slide    : TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69
#   Clusters : cluster_scoring_polygons.geojson
#   Output   : vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/spatial_feature_results/necrosis_proximity
# =======================================================
#   Clusters:             3
#   Segmentation regions: 17777
# Computing necrosis proximity: 100%|██████████| 3/3 [00:15<00:00,  5.15s/cluster]
#   Wrote: necrosis_proximity_by_cluster.csv
#   Wrote: necrosis_proximity_wsi_summary.csv
#   Wrote: necrosis_distance_figure.png
#   Wrote: necrosis_tissue_context_figure.png
#
#   === Necrosis proximity summary ===
#   Total necrosis area:          0.446 mm²
#   Necrosis fraction of cluster: 0.022
#   Intratumoral fraction:        0.034
#   Immune coupling index:        0.540
#   Dominant phenotype:           peritumoural
#
#   Done.
#   ✓  [necrosis_proximity] done in 28.5s
#
#   ▶  [tumor_morphology] starting …
#
# =======================================================
#   Tumour morphology features
#   Slide              : TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69
#   min_island_area_um2: 1000
#   Clusters           : cluster_scoring_polygons.geojson
#   Output             : vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/spatial_feature_results/tumor_morphology
# =======================================================
#   Loaded 1,831 tumour polygons from 17,777 GeoJSON features.
# Computing tumour morphology: 100%|██████████| 3/3 [00:04<00:00,  1.35s/cluster]
#   Wrote: tumor_core_features_by_cluster.csv
#   Wrote: tumor_core_wsi_summary.csv
#
#   === Tumour morphology summary ===
#   Clusters scored:         3
#   Total tumour area:       5.615 mm²
#   Total islands (filtered):244
#   Mean fragmentation index:0.634
#   Mean compactness:        0.104
#
#   Done.
#   ✓  [tumor_morphology] done in 11.5s
#
# ############################################################
#   ✓  Pipeline complete for TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69  (428.1s total)
# ############################################################
#
#   Stage                            Status         Time
#   -------------------------------- ---------- --------
#   ✓ tessellation                    done          74.8s
#   ✓ segmentation                    done         125.1s
#   ✓ stitching                       done         136.4s
#   ✓ tumor_roi_overlay               done           5.5s
#   ✓ cluster_tils_tsr_score          done          20.0s
#   ✓ immune_proximity                done          26.2s
#   ✓ necrosis_proximity              done          28.5s
#   ✓ tumor_morphology                done          11.5s
#
# No stages failed in the last run.

# %%
from generate_report import generate_report

report_path = generate_report(cfg=cfg, author="Himangi Srivastava", notes="TNBC, TCGA example slide")
# Out:
# Rendering report for: TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69
# Output: report/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69_report.html
# Starting tcrdist kernel...
# ---------------------------------------------------------------------------
# ReportGenerationError                     Traceback (most recent call last)
# Cell In[2], line 3
#       1 from generate_report import generate_report
# ----> 3 report_path = generate_report(cfg=cfg, author="Himangi Srivastava", notes="TNBC, TCGA example slide")
#
# File ~/ViP-SegD/VipSegD_v1/generate_report.py:150, in generate_report(slide, out, report_dir, author, notes, cfg)
#     148 result = subprocess.run(cmd)
#     149 if result.returncode != 0:
# --> 150     raise ReportGenerationError(
#     151         f"quarto render failed with exit code {result.returncode}. "
#     152         f"See the output above for details."
#     153     )
#     155 print(f"\nDone. Report saved to:\n  {out_html.resolve()}")
#     156 return out_html
#
# ReportGenerationError: quarto render failed with exit code 1. See the output above for details.

# %% [markdown]
# ## Combined per-cluster feature table
#
# Merge all per-cluster CSVs into one wide feature table — one row per tumour cluster,
# all features side by side.  This is the table you would use as input to a
# survival model or classifier.

# %%
from pathlib import Path
import pandas as pd

slide_name = Path(cfg.WSI_PATH).stem
sf = Path(cfg.OUT_DIR) / slide_name / 'spatial_feature_results'

csv_map = {
    'tils':    sf / 'cluster_tils_tsr_score'  / 'tils_tsr_by_cluster.csv',
    'immune':  sf / 'immune_proximity'         / 'immune_proximity_by_cluster.csv',
    'necrosis':sf / 'necrosis_proximity'       / 'necrosis_proximity_by_cluster.csv',
    'morpho':  sf / 'tumor_morphology'         / 'tumor_core_features_by_cluster.csv',
}

frames = {}
for key, path in csv_map.items():
    if path.exists():
        frames[key] = pd.read_csv(path)
        print(f'  Loaded {key:10s}: {len(frames[key]):>3} rows × {frames[key].shape[1]:>3} cols')
    else:
        print(f'  ✗ {key}: not yet generated')

if frames:
    base = next(iter(frames.values()))[['cluster_id']].copy()
    for key, df in frames.items():
        # Drop columns that exist in other frames to avoid _x / _y collisions
        drop_cols = [c for c in df.columns if c in base.columns and c != 'cluster_id']
        base = base.merge(df.drop(columns=drop_cols), on='cluster_id', how='left')

    print(f'\nCombined table: {base.shape[0]} clusters × {base.shape[1]} features')
    display(base.head())

    # Save to disk
    out_path = sf / 'combined_features_by_cluster.csv'
    base.to_csv(out_path, index=False)
    print(f'\nSaved → {out_path}')
# Out:
#   Loaded tils      :   3 rows ×  56 cols
#   Loaded immune    :   3 rows ×  20 cols
#   Loaded necrosis  :   3 rows ×  23 cols
#   Loaded morpho    :   3 rows ×  38 cols
#
# Combined table: 3 clusters × 124 features
#    cluster_id  n_roi_boxes  priority_nonoverlap  cluster_scoring_area_px2  \
# 0           0          282                    1              2.701108e+08
# 1           3           36                    2              4.278237e+07
# 2           4            5                    3              8.934934e+06
#
#    cluster_scoring_area_um2  cluster_scoring_perimeter_px  \
# 0              1.688193e+07                  88234.677894
# 1              2.673898e+06                  28785.854479
# 2              5.584334e+05                  12541.795212
#
#    cluster_scoring_perimeter_um  buffer_um  tumor_area_px2  tumor_area_um2  \
# 0                  22058.669473      200.0    8.189720e+07    5.118575e+06
# 1                   7196.463620      200.0    7.332438e+06    4.582774e+05
# 2                   3135.448803      200.0    6.068584e+05    3.792865e+04
#
#    ...  tumor_island_area_median_um2  tumor_island_area_p90_um2  \
# 0  ...                   2723.531250               43822.296875
# 1  ...                   2314.346543               17245.318750
# 2  ...                   3329.066001                6648.843750
#
#    tumor_island_area_max_um2  tumor_island_nnd_mean_um  \
# 0               1.617432e+06                126.292934
# 1               1.659273e+05                140.876585
# 2               1.045903e+04                189.271622
#
#    tumor_island_nnd_median_um  tumor_spread_frac  tumor_convex_hull_fill  \
# 0                  115.873314           0.908001                0.342495
# 1                  129.138930           0.665440                0.492048
# 2                  108.252183           0.776787                0.137467
#
#    min_island_area_um2_used  tumor_valid_morphology  tumor_invalid_reason
# 0                    1000.0                    True                   NaN
# 1                    1000.0                    True                   NaN
# 2                    1000.0                    True                   NaN
#
# [3 rows x 124 columns]
# Saved → vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/spatial_feature_results/combined_features_by_cluster.csv

# %% [markdown]
# ## WSI-level summary
#
# Merge all WSI-level summary rows into one horizontal table.  This gives the
# single-row feature vector for the whole slide.

# %%
wsi_csv_map = {
    'tils':    sf / 'cluster_tils_tsr_score'  / 'tils_tsr_wsi_summary.csv',
    'immune':  sf / 'immune_proximity'         / 'immune_proximity_wsi_summary.csv',
    'necrosis':sf / 'necrosis_proximity'       / 'necrosis_proximity_wsi_summary.csv',
    'morpho':  sf / 'tumor_morphology'         / 'tumor_core_wsi_summary.csv',
}

wsi_frames = {}
for key, path in wsi_csv_map.items():
    if path.exists():
        wsi_frames[key] = pd.read_csv(path)

if wsi_frames:
    combined_wsi = pd.concat(
        [df.reset_index(drop=True) for df in wsi_frames.values()],
        axis=1
    )
    # Remove duplicate columns (e.g. n_clusters)
    combined_wsi = combined_wsi.loc[:, ~combined_wsi.columns.duplicated()]
    print(f'WSI feature vector: {combined_wsi.shape[1]} features')
    display(combined_wsi.T)

    wsi_out = sf / 'combined_wsi_summary.csv'
    combined_wsi.to_csv(wsi_out, index=False)
    print(f'\nSaved → {wsi_out}')
# Out:
# WSI feature vector: 120 features
#                                                      0
# tils_denominator_used                          salgado
# mpp                                               0.25
# n_clusters_input                                    10
# n_clusters_scored                                    3
# n_clusters_filtered_min_roi                          7
# ...                                                ...
# wsi_area_weighted_tumor_convex_hull_fill      0.353317
# wsi_island_area_mean_um2                  21968.483235
# wsi_island_area_median_um2                  2706.65625
# wsi_island_area_p90_um2                   40424.228125
# wsi_island_area_max_um2                   1617432.1875
#
# [120 rows x 1 columns]
# Saved → vipsegd_output/TCGA-S3-AA10-01Z-00-DX1.C0468882-0DD8-4FC5-8C2F-E18BE8000F69/spatial_feature_results/combined_wsi_summary.csv

# %% [markdown]
# ## Output file inventory
#
# List every file produced by the pipeline, grouped by stage.

# %%
import os

slide_name = Path(WSI_PATH).stem
out_root   = Path(cfg.OUT_DIR) / slide_name

total_size = 0
for dirpath, _, filenames in os.walk(out_root):
    rel = Path(dirpath).relative_to(out_root)
    if filenames:
        print(f'  {rel}/')
        for fname in sorted(filenames):
            fpath = Path(dirpath) / fname
            size  = fpath.stat().st_size
            total_size += size
            size_str = f'{size/1e6:.2f} MB' if size > 1e6 else f'{size/1e3:.1f} KB'
            print(f'    {fname:<55} {size_str:>10}')

print(f'\nTotal output size: {total_size/1e6:.1f} MB')

# %%
from generate_qmd_file import generate_report
report_qmd = generate_report(
    wsi_path=cfg.WSI_PATH,
    cfg=cfg,
)

print(f"Generated report file: {report_qmd}")
# Out:
# Generated report file: vipsegd_report_slide.qmd
